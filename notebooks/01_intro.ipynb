# %% [markdown]
# # EinführungDieses Notebook läuft über mybinder.org (keine Installation nötig).**Speicherhinweis:** In Binder regelmäßig Datei → Download (.ipynb).

# %%
import sys, platform, numpy as np, pandas as pd, matplotlibprint('Python:', sys.version.split()[0])print('Platform:', platform.platform())print('numpy:', np.__version__)print('pandas:', pd.__version__)print('matplotlib:', matplotlib.__version__)

# %%
import pandas as pddf = pd.DataFrame({'x':[1,2,3], 'y':[3,2,1]})df
